# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/Ebookhttps://en.wikipedia.org/wiki/Ebook"
r = requests.get(url)

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Ebookhttps://en.wikipedia.org/wiki/Ebook - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"38e254c8-2be0-4e1f-bd7b-b59e4baa89d2","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Ebookhttps://en.wikipedia.org/wiki/Ebook","wgTitle":"Ebookhttps://en.wikipedia.org/wiki/Ebook","wgCurRevisionId":0,"wgRevisionId":0,"wgArticleId":0,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Ebo
# ...

# %%
root = BeautifulSoup(r.content, 'html5lib')
print(root.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Ebookhttps://en.wikipedia.org/wiki/Ebook - Wikipedia
#   </title>
#   <script>
# ...

# %%
table = root.find('table')
print(table)
# Out:
# <table class="plainlinks fmbox fmbox-system" id="noarticletext" role="presentation"><tbody><tr><td class="mbox-text" style="padding: 0.6em 0.9em;"><style data-mw-deduplicate="TemplateStyles:r1080588920">.mw-parser-output .no-article-text-sister-projects{border:1px solid #a2a9b1;background-color:#f8f9fa;line-height:1.5em;font-size:90%;padding:0.5em}.mw-parser-output .no-article-text-sister-projects li{display:flex;align-items:center}.mw-parser-output .no-article-text-sister-projects li>div:first-child{text-align:center;width:30px;height:30px;margin-right:0.3em;flex:0 0 30px}@media all and (min-width:40em){.mw-parser-output .no-article-text-sister-projects{margin:0.5em 0 0.5em 1em;clear:right;width:20em;float:right}.mw-parser-output .no-article-text-sister-projects .plainlist{margin-left:2em}.mw-parser-output .no-article-text-sister-projects li{height:2.5em}}</style><div class="no-article-text-sister-projects" id="sisterproject">Look for <b>Ebookhttps://en.wikipedia.org/wiki/Ebook</b> 
# ...

# %%
for i in table.find_all('div', attrs = {'class':'plainlist'}):
  print (table.get_text())
# Out:
# .mw-parser-output .no-article-text-sister-projects{border:1px solid #a2a9b1;background-color:#f8f9fa;line-height:1.5em;font-size:90%;padding:0.5em}.mw-parser-output .no-article-text-sister-projects li{display:flex;align-items:center}.mw-parser-output .no-article-text-sister-projects li>div:first-child{text-align:center;width:30px;height:30px;margin-right:0.3em;flex:0 0 30px}@media all and (min-width:40em){.mw-parser-output .no-article-text-sister-projects{margin:0.5em 0 0.5em 1em;clear:right;width:20em;float:right}.mw-parser-output .no-article-text-sister-projects .plainlist{margin-left:2em}.mw-parser-output .no-article-text-sister-projects li{height:2.5em}}Look for Ebookhttps://en.wikipedia.org/wiki/Ebook on one of Wikipedia's sister projects:
#
#
#
#
#   Wiktionary (dictionary)
#
#
#
#   Wikibooks (textbooks)
#
#
#
#   Wikiquote (quotations)
#
#
#
#   Wikisource (library)
#
#
#
#   Wikiversity (learning resources)
#
#
#
#   Commons (media)
#
#
#
#   Wikivoyage (travel guide)
#
#
#
# ...

# %%
div = table.find('img') 
print(div)
# Out:
# <img alt="" data-file-height="391" data-file-width="391" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/30px-Wiktionary-logo-v2.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/45px-Wiktionary-logo-v2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/60px-Wiktionary-logo-v2.svg.png 2x" width="30"/>

# %%
for item in div.findAll('a', attrs = {'id':'extiw'}): 
  print(div)

# %%
extract = table.find('ul')
print(extract)
# Out:
# <ul>
# <li>
#   <div><img alt="" data-file-height="391" data-file-width="391" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/30px-Wiktionary-logo-v2.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/45px-Wiktionary-logo-v2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/60px-Wiktionary-logo-v2.svg.png 2x" width="30"/></div>
#   <div><a class="extiw" href="https://en.wiktionary.org/wiki/Special:Search/Ebookhttps://en.wikipedia.org/wiki/Ebook" title="wiktionary:Special:Search/Ebookhttps://en.wikipedia.org/wiki/Ebook">Wiktionary</a> (dictionary)</div>
# </li>
# <li>
# ...

# %%
reextract = extract.findAll('li')

# %%
for items in extract.findAll('li'): 
 lists = (extract.get_text())
 print(lists)
# Out:
#
#   Wiktionary (dictionary)
#
#
#
#   Wikibooks (textbooks)
#
#
#
#   Wikiquote (quotations)
#
#
#
#   Wikisource (library)
#
#
#
#   Wikiversity (learning resources)
#
#
#
#   Commons (media)
#
#
#
#   Wikivoyage (travel guide)
#
#
#
#   Wikinews (news source)
#
#
#
#   Wikidata (linked database)
#
#
#
#   Wikispecies (species directory)
#
#
#
#
#
#   Wiktionary (dictionary)
#
#
#
#   Wikibooks (textbooks)
#
#
#
#   Wikiquote (quotations)
#
#
#
#   Wikisource (library)
#
#
#
#   Wikiversity (learning resources)
#
#
#
#   Commons (media)
#
#
#
#   Wikivoyage (travel guide)
#
#
#
#   Wikinews (news source)
#
#
#
#   Wikidata (linked database)
#
#
#
#   Wikispecies (species directory)
#
#
#
#
#
#   Wiktionary (dictionary)
#
#
#
#   Wikibooks (textbooks)
#
#
#
#   Wikiquote (quotations)
#
#
#
#   Wikisource (library)
#
#
#
#   Wikiversity (learning resources)
#
#
#
#   Commons (media)
#
#
#
#   Wikivoyage (travel guide)
#
#
#
#   Wikinews (news source)
#
#
#
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
table = soup.find_all('h3',attrs={'class':"vector-menu-heading "})
array = []
for i in table:
 data = i.text.replace('\n', ' ').strip()
 array.append(data)
for q in array:
 print(q)
# Out:
# Personal tools
# Namespaces
# Views
# Navigation
# Contribute
# Tools
# Languages
